# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# %%
movies = pd.read_csv('data/movies.csv')
names = pd.read_csv('data/names.csv')
ratings = pd.read_csv('data/ratings.csv')
princ = pd.read_csv('data/title_principals.csv')
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
names.head()
# Out:
#   imdb_name_id             name               birth_name  height  \
# 0    nm0000001     Fred Astaire  Frederic Austerlitz Jr.   177.0
# 1    nm0000002    Lauren Bacall        Betty Joan Perske   174.0
# 2    nm0000003  Brigitte Bardot          Brigitte Bardot   166.0
# 3    nm0000004     John Belushi        John Adam Belushi   170.0
# 4    nm0000005   Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                  bio  \
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
# 3  John Belushi was born in Chicago, Illinois, US...
# 4  Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                        birth_details date_of_birth  \
# 0               May 10, 1899 in Omaha, Nebraska, USA    1899-05-10
# 1  September 16, 1924 in The Bronx, New York City...    1924-09-16
# ...

# %%
ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
princ.head()
# Out:
#   imdb_title_id  ordering imdb_name_id  category  job  \
# 0     tt0000009         1    nm0063086   actress  NaN
# 1     tt0000009         2    nm0183823     actor  NaN
# 2     tt0000009         3    nm1309758     actor  NaN
# 3     tt0000009         4    nm0085156  director  NaN
# 4     tt0000574         1    nm0846887   actress  NaN
#
#                                           characters
# 0           ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1                                   ["Mr. Hamilton"]
# 2  ["Chauncey Depew - the Director of the New Yor...
# 3                                                NaN
# 4                                     ["Kate Kelly"]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdb_title_id              85855 non-null  object
#  1   weighted_average_vote      85855 non-null  float64
#  2   total_votes                85855 non-null  int64
#  3   mean_vote                  85855 non-null  float64
#  4   median_vote                85855 non-null  float64
#  5   votes_10                   85855 non-null  int64
#  6   votes_9                    85855 non-null  int64
#  7   votes_8                    85855 non-null  int64
#  8   votes_7                    85855 non-null  int64
#  9   votes_6                    85855 non-null  int64
#  10  votes_5                    85855 non-null  int64
#  11  votes_4                    85855 non-null  int64
#  12  votes_3                    85855 non-null  int64
# ...

# %%
df = pd.concat([movies, ratings], axis = 1)

# %%
df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics', 'imdb_title_id',
#        'weighted_average_vote', 'total_votes', 'mean_vote', 'median_vote',
#        'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6', 'votes_5',
#        'votes_4', 'votes_3', 'votes_2', 'votes_1', 'allgenders_0age_avg_vote',
#        'allgenders_0age_votes', 'allgenders_18age_avg_vote',
#        'allgenders_18age_votes', 'allgenders_30age_avg_vote',
#        'allgenders_30age_votes', 'allgenders_45age_avg_vote',
#        'allgenders_45age_votes', 'males_allages_avg_vote',
#        'males_allages_votes', 'males_0age_avg_vote', 'males_0age_votes',
# ...

# %%
features = ['imdb_title_id', 'title', 'year', 'genre', 'duration', 'country', 'language', 'director', 'writer',
            'actors', 'description', 'weighted_average_vote', 'mean_vote', 'reviews_from_users', 
            'reviews_from_critics', 'females_allages_avg_vote', 'males_allages_avg_vote']

# %%
ddf = df[features]

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   imdb_title_id             85855 non-null  object
#  1   imdb_title_id             85855 non-null  object
#  2   title                     85855 non-null  object
#  3   year                      85855 non-null  object
#  4   genre                     85855 non-null  object
#  5   duration                  85855 non-null  int64
#  6   country                   85791 non-null  object
#  7   language                  85022 non-null  object
#  8   director                  85768 non-null  object
#  9   writer                    84283 non-null  object
#  10  actors                    85786 non-null  object
#  11  description               83740 non-null  object
#  12  weighted_average_vote     85855 non-null  float64
# ...

# %%
ddf = ddf.loc[:,~ddf.columns.duplicated()]

# %%
ddf
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
ddf.isnull().sum()
# Out:
# imdb_title_id                   0
# title                           0
# year                            0
# genre                           0
# duration                        0
# country                        64
# language                      833
# director                       87
# writer                       1572
# actors                         69
# description                  2115
# weighted_average_vote           0
# mean_vote                       0
# reviews_from_users           7597
# reviews_from_critics        11797
# females_allages_avg_vote       81
# males_allages_avg_vote          1
# dtype: int64

# %%
ddf['reviews_from_critics'] = ddf['reviews_from_critics'].fillna('unavailable')
ddf['reviews_from_users'] = ddf['reviews_from_users'].fillna('unavailable')
ddf['writer'] = ddf['writer'].fillna('unavailable')
ddf['country'] = ddf['country'].fillna('unavailable')
ddf['language'] = ddf['language'].fillna('unavailable')
ddf['director'] = ddf['director'].fillna('unavailable')
ddf['actors'] = ddf['actors'].fillna('unavailable')
ddf['description'] = ddf['description'].fillna('unavailable')

# %%
ddf.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# year                         0
# genre                        0
# duration                     0
# country                      0
# language                     0
# director                     0
# writer                       0
# actors                       0
# description                  0
# weighted_average_vote        0
# mean_vote                    0
# reviews_from_users           0
# reviews_from_critics         0
# females_allages_avg_vote    81
# males_allages_avg_vote       1
# dtype: int64

# %%
ddf.dropna(inplace = True)

# %%
ddf.isnull().sum()
# Out:
# imdb_title_id               0
# title                       0
# year                        0
# genre                       0
# duration                    0
# country                     0
# language                    0
# director                    0
# writer                      0
# actors                      0
# description                 0
# weighted_average_vote       0
# mean_vote                   0
# reviews_from_users          0
# reviews_from_critics        0
# females_allages_avg_vote    0
# males_allages_avg_vote      0
# dtype: int64

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85773 entries, 0 to 85854
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   imdb_title_id             85773 non-null  object
#  1   title                     85773 non-null  object
#  2   year                      85773 non-null  object
#  3   genre                     85773 non-null  object
#  4   duration                  85773 non-null  int64
#  5   country                   85773 non-null  object
#  6   language                  85773 non-null  object
#  7   director                  85773 non-null  object
#  8   writer                    85773 non-null  object
#  9   actors                    85773 non-null  object
#  10  description               85773 non-null  object
#  11  weighted_average_vote     85773 non-null  float64
#  12  mean_vote                 85773 non-null  float64
# ...

# %%
link = ['https://www.imdb.com/title/'] + ddf['imdb_title_id']

# %%
link
# Out:
# 0        https://www.imdb.com/title/tt0000009
# 1        https://www.imdb.com/title/tt0000574
# 2        https://www.imdb.com/title/tt0001892
# 3        https://www.imdb.com/title/tt0002101
# 4        https://www.imdb.com/title/tt0002130
#                          ...
# 85849    https://www.imdb.com/title/tt9906644
# 85850    https://www.imdb.com/title/tt9908390
# 85851    https://www.imdb.com/title/tt9911196
# 85853    https://www.imdb.com/title/tt9914286
# 85854    https://www.imdb.com/title/tt9914942
# Name: imdb_title_id, Length: 85773, dtype: object

# %%
ddf['link'] = link

# %%
ddf
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85849     tt9906644                       Manoharam  2019
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib3

# %%
images = []
for i in ddf['link']:
    r = requests.get(i)
    soup = BeautifulSoup(r.content, "html.parser")
    link = soup.find(itemprop="image")
    if link is None:
        images.append(np.nan)
    else:
        images.append(link.attrs['src'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-da4558ad4fa0> in <module>
#       1 images = []
#       2 for i in ddf['link']:
# ----> 3     r = requests.get(i)
#       4     soup = BeautifulSoup(r.content, "html.parser")
#       5     link = soup.find(itemprop="image")
#
# E:\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# E:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
images = []
for i in ddf['imdb_title_id']:
    film_id = i
    url = 'http://www.imdb.com/title/' + (film_id)
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html5lib')
    link = soup.find(itemprop="image")
    if link is None:
        img.append(np.nan)
    else:
        img.append(link.attrs['src'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-86eb2992f79d> in <module>
#       3     film_id = i
#       4     url = 'http://www.imdb.com/title/' + (film_id)
# ----> 5     r = requests.get(url)
#       6     soup = BeautifulSoup(r.content, 'html5lib')
#       7     link = soup.find(itemprop="image")
#
# E:\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# E:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
# Out:
# [nan]

# %%
ddf.to_csv('data/cleaned.csv', index = False)
